# %% [markdown]
# # STEP -1

# %% [markdown]
# ## Import Libraries and Create connection

# %%
import os
import json
from datetime import timedelta, datetime
from bson import json_util
from dotenv import load_dotenv
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, date_format, lit

# %%
load_dotenv(".env")
mongo_url = os.getenv("mongo_url")

# %%
spark = (
    SparkSession.builder
        .appName("MongoDBReadJoin")
        .master("local[*]")
        .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.3.0")
        .getOrCreate()
)

# %% [markdown]
# # STEP - 2

# %% [markdown]
# ## User pipeline

# %%
user_email = input("Enter user email: ").strip()
print(user_email)
# Out:
# nirmallya@klizos.com

# %%
pipeline_users = json.dumps([
    {"$match": {"email": user_email}},
    {"$project": {
        "_id": 1,
        "username": 1,
        "email": 1,
        "role": 1
    }}
])

pipeline_users
# Out:
# '[{"$match": {"email": "nirmallya@klizos.com"}}, {"$project": {"_id": 1, "username": 1, "email": 1, "role": 1}}]'

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://54.216.237.221:27017", serverSelectionTimeoutMS=5000)
print(client.server_info())
# Out:
# {'version': '8.0.11', 'gitVersion': 'bed99f699da6cb2b74262aa6d473446c41476643', 'modules': [], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 11, 0], 'openssl': {'running': 'OpenSSL 3.0.13 30 Jan 2024', 'compiled': 'OpenSSL 3.0.13 30 Jan 2024'}, 'buildEnvironment': {'distmod': 'ubuntu2404', 'distarch': 'x86_64', 'cc': '/opt/mongodbtoolchain/v4/bin/gcc: gcc (GCC) 11.3.0', 'ccflags': '-Werror -include mongo/platform/basic.h -ffp-contract=off -fasynchronous-unwind-tables -g2 -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -gdwarf-5 -fno-omit-frame-pointer -fno-strict-aliasing -O2 -march=sandybridge -mtune=generic -mprefer-vector-width=128 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-const-variable -Wno-unused-but-set-variable -Wno-missing-braces -Wno-psabi -fstack-protector-strong -gdwarf64 -Wa,--nocompress-debug-sections -fno-builtin-memcmp -Wimplicit-fallthrough=5', 'cxx': '/opt/mongodbtoolchain/v4/bin/g++: g++ (GCC) 11.3.0', 'cxxflags': '-Woverloaded-virtual -Wpessimizing-move -Wno-maybe-uninitialized -fsized-deallocation -std=c++20', 'linkflags': '-Wl,--fatal-warnings -B/opt/mongodbtoolchain/v4/bin -gdwarf-5 -pthread -Wl,-z,now -fuse-ld=lld -fstack-protector-strong -gdwarf64 -Wl,--build-id -Wl,--hash-style=gnu -Wl,-z,noexecstack -Wl,--warn-execstack -Wl,-z,relro -Wl,--compress-debug-sections=none -Wl,-z,origin -Wl,--enable-new-dtags', 'target_arch': 'x86_64', 'target_os': 'linux', 'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE2_STATIC ABSL_ALLOCATOR_NOTHROW NDEBUG _XOPEN_SOURCE 700 _GNU_SOURCE _FORTIFY_SOURCE 2 ABSL_FORCE_ALIGNED_ACCESS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_FILESYSTEM_NO_CXX20_ATOMIC_REF BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_SYSTEM_NO_DEPRECATED BOOST_THREAD_USES_DATETIME BOOST_THREAD_VERSION 5'}, 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'wiredTiger'], 'ok': 1.0}

# %%
df_users = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "users")
        .load()
        .filter(col("email") == user_email)   # <-- Spark filter
        .select("_id", "username", "email", "role")
)

user_data = df_users.limit(1).collect()
user_data
# Out:
# [Row(_id='6874c8bd378bbb7f8e9c07bd', username='nirmallya', email='nirmallya@klizos.com', role='employee')]

# %%
user_id = user_data[0]["_id"]
username = user_data[0]["username"]
role = user_data[0]["role"]

print(f"Found user: {username} ({role}), _id={user_id}")
# Out:
# Found user: nirmallya (employee), _id=6874c8bd378bbb7f8e9c07bd

# %% [markdown]
# ## Agentic Activity pipeline

# %%
filter_date = input("Enter date (yyyy-MM-dd): ").strip()

start_date = datetime.strptime(filter_date, "%Y-%m-%d")
end_date = start_date + timedelta(days=1)

filter_date
# Out:
# '2025-08-20'

# %% [markdown]
# ### Calculating Total Duration of the Date

# %%
pipeline_total_duration = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$group": {
            "_id": {
                "date": {
                    "$dateToString": {
                        "format": "%Y-%m-%d",
                        "date": "$timestamp",
                        "timezone": "Asia/Kolkata"
                    }
                }
            },
            "min_timestamp": {"$min": "$timestamp"},
            "max_timestamp": {"$max": "$timestamp"}
        }
    },
    {
        "$project": {
            "date": "$_id.date",
            "min_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$min_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "max_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$max_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    }
]

pipeline_total_duration_json = json.dumps(pipeline_total_duration, default=json_util.default)

df_base = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "agentactivities")
        .option("aggregation.pipeline", pipeline_total_duration_json)
        .load()
)

# Now calculate durations in Spark
from pyspark.sql.functions import unix_timestamp, to_timestamp

df_final = (
    df_base
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .withColumn("min_ts", to_timestamp("min_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("max_ts", to_timestamp("max_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("total_duration_minutes", (unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 60)
    .withColumn("total_duration_hours", (unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 3600)
    .select(
        "username", "email", "role",
        "date", "min_timestamp", "max_timestamp",
        "total_duration_minutes", "total_duration_hours"
    )
)

df_final.show(truncate=False)
# Out:
# +---------+--------------------+--------+----------+-------------------+-------------------+----------------------+--------------------+
# |username |email               |role    |date      |min_timestamp      |max_timestamp      |total_duration_minutes|total_duration_hours|
# +---------+--------------------+--------+----------+-------------------+-------------------+----------------------+--------------------+
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|2025-08-20 12:53:04|2025-08-20 22:32:04|579.0                 |9.65                |
# +---------+--------------------+--------+----------+-------------------+-------------------+----------------------+--------------------+

# %% [markdown]
# ## Calculate total duration for the 'type' column

# %%
# Aggregation pipeline to calculate min/max timestamps per user per type per day
pipeline_duration_by_type = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$group": {
            "_id": {
                "date": {
                    "$dateToString": {
                        "format": "%Y-%m-%d",
                        "date": "$timestamp",
                        "timezone": "Asia/Kolkata"
                    }
                },
                "type": "$type"  # group by type
            },
            "min_timestamp": {"$min": "$timestamp"},
            "max_timestamp": {"$max": "$timestamp"}
        }
    },
    {
        "$project": {
            "date": "$_id.date",
            "type": "$_id.type",
            "min_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$min_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "max_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$max_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    }
]

pipeline_duration_by_type_json = json.dumps(pipeline_duration_by_type, default=json_util.default)

# Read from MongoDB with the updated pipeline
df_type = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "agentactivities")
        .option("aggregation.pipeline", pipeline_duration_by_type_json)
        .load()
)

# Calculate durations in Spark
from pyspark.sql.functions import round as spark_round

df_final_type = (
    df_type
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .withColumn("min_ts", to_timestamp("min_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("max_ts", to_timestamp("max_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("total_duration_minutes", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 60, 5))
    .withColumn("total_duration_hours", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 3600, 5))
    .select(
        "username", "email", "role", "date", "type",
        "min_timestamp", "max_timestamp",
        "total_duration_minutes", "total_duration_hours"
    )
)

df_final_type.show(truncate=False)
# Out:
# +---------+--------------------+--------+----------+----------------+-------------------+-------------------+----------------------+--------------------+
# |username |email               |role    |date      |type            |min_timestamp      |max_timestamp      |total_duration_minutes|total_duration_hours|
# +---------+--------------------+--------+----------+----------------+-------------------+-------------------+----------------------+--------------------+
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|keystroke       |2025-08-20 12:53:04|2025-08-20 22:32:03|578.98333             |9.64972             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |2025-08-20 12:53:04|2025-08-20 22:31:59|578.91667             |9.64861             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|2025-08-20 12:53:26|2025-08-20 22:32:04|578.63333             |9.64389             |
# +---------+--------------------+--------+----------+----------------+-------------------+-------------------+----------------------+--------------------+

# %% [markdown]
# ## Calculate total duration for the 'application_name' column

# %%
# Aggregation pipeline to calculate min/max timestamps per user per application per day
pipeline_duration_by_app = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$group": {
            "_id": {
                "date": {
                    "$dateToString": {
                        "format": "%Y-%m-%d",
                        "date": "$timestamp",
                        "timezone": "Asia/Kolkata"
                    }
                },
                "application_name": "$application.name"  # group by application.name
            },
            "min_timestamp": {"$min": "$timestamp"},
            "max_timestamp": {"$max": "$timestamp"}
        }
    },
    {
        "$project": {
            "date": "$_id.date",
            "application_name": "$_id.application_name",
            "min_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$min_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "max_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$max_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    }
]

pipeline_duration_by_app_json = json.dumps(pipeline_duration_by_app, default=json_util.default)

# Read from MongoDB with the updated pipeline
df_app = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "agentactivities")
        .option("aggregation.pipeline", pipeline_duration_by_app_json)
        .load()
)

# Calculate durations in Spark
from pyspark.sql.functions import round as spark_round

df_final_app = (
    df_app
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .withColumn("min_ts", to_timestamp("min_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("max_ts", to_timestamp("max_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("total_duration_minutes", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 60, 5))
    .withColumn("total_duration_hours", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 3600, 5))
    .select(
        "username", "email", "role", "date", "application_name",
        "min_timestamp", "max_timestamp",
        "total_duration_minutes", "total_duration_hours"
    )
)

df_final_app.show(truncate=False)
# Out:
# +---------+--------------------+--------+----------+-----------------------------+-------------------+-------------------+----------------------+--------------------+
# |username |email               |role    |date      |application_name             |min_timestamp      |max_timestamp      |total_duration_minutes|total_duration_hours|
# +---------+--------------------+--------+----------+-----------------------------+-------------------+-------------------+----------------------+--------------------+
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Store                        |2025-08-20 15:58:22|2025-08-20 16:09:49|11.45                 |0.19083             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Slack                        |2025-08-20 12:53:36|2025-08-20 22:31:36|578.0                 |9.63333             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Store Installer              |2025-08-20 15:47:10|2025-08-20 16:05:17|18.11667              |0.30194             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Windows Shell Experience Host|2025-08-20 12:55:17|2025-08-20 22:10:47|555.5                 |9.25833             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Windows Explorer             |2025-08-20 12:53:04|2025-08-20 22:10:29|557.41667             |9.29028             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Application Frame Host       |2025-08-20 15:57:57|2025-08-20 16:08:24|10.45                 |0.17417             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Google Chrome                |2025-08-20 13:15:08|2025-08-20 22:31:57|556.81667             |9.28028             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Visual Studio Code           |2025-08-20 14:55:16|2025-08-20 14:57:06|1.83333               |0.03056             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Task Manager                 |2025-08-20 13:49:17|2025-08-20 15:25:08|95.85                 |1.5975              |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Cursor                       |2025-08-20 13:01:12|2025-08-20 21:28:58|507.76667             |8.46278             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Unknown                      |2025-08-20 15:48:17|2025-08-20 22:21:43|393.43333             |6.55722             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Settings                     |2025-08-20 16:04:32|2025-08-20 16:43:44|39.2                  |0.65333             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Search application           |2025-08-20 15:57:37|2025-08-20 15:57:52|0.25                  |0.00417             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Console Window Host          |2025-08-20 14:55:04|2025-08-20 14:55:09|0.08333               |0.00139             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Windows Command Processor    |2025-08-20 14:53:24|2025-08-20 14:54:59|1.58333               |0.02639             |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|Electron                     |2025-08-20 12:53:04|2025-08-20 22:32:04|579.0                 |9.65                |
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|ScreenClippingHost.exe       |2025-08-20 20:02:35|2025-08-20 20:02:46|0.18333               |0.00306             |
# +---------+--------------------+--------+----------+-----------------------------+-------------------+-------------------+----------------------+--------------------+

# %% [markdown]
# ## Calculate total duration for the 'window_title' column

# %%
# Aggregation pipeline to calculate min/max timestamps per user per window.title per day
pipeline_duration_by_window = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$group": {
            "_id": {
                "date": {
                    "$dateToString": {
                        "format": "%Y-%m-%d",
                        "date": "$timestamp",
                        "timezone": "Asia/Kolkata"
                    }
                },
                "window_title": "$window.title"  # group by window.title
            },
            "min_timestamp": {"$min": "$timestamp"},
            "max_timestamp": {"$max": "$timestamp"}
        }
    },
    {
        "$project": {
            "date": "$_id.date",
            "window_title": "$_id.window_title",
            "min_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$min_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "max_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$max_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    }
]

pipeline_duration_by_window_json = json.dumps(pipeline_duration_by_window, default=json_util.default)

# Read from MongoDB with the updated pipeline
df_window = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "agentactivities")
        .option("aggregation.pipeline", pipeline_duration_by_window_json)
        .load()
)

# Calculate durations in Spark
from pyspark.sql.functions import round as spark_round

df_final_window = (
    df_window
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .withColumn("min_ts", to_timestamp("min_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("max_ts", to_timestamp("max_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("total_duration_minutes", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 60, 5))
    .withColumn("total_duration_hours", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 3600, 5))
    .select(
        "username", #"email", "role", 
        "date", 
        "window_title",
        "min_timestamp", "max_timestamp",
        "total_duration_minutes", "total_duration_hours"
    )
)

df_final_window.show(10)
# Out:
# +---------+----------+--------------------+-------------------+-------------------+----------------------+--------------------+
# | username|      date|        window_title|      min_timestamp|      max_timestamp|total_duration_minutes|total_duration_hours|
# +---------+----------+--------------------+-------------------+-------------------+----------------------+--------------------+
# |nirmallya|2025-08-20|cursor/dashboard ...|2025-08-20 15:48:20|2025-08-20 15:48:20|                   0.0|                 0.0|
# |nirmallya|2025-08-20|chatgpy desktop d...|2025-08-20 16:07:13|2025-08-20 16:07:13|                   0.0|                 0.0|
# |nirmallya|2025-08-20|Untitled - Google...|2025-08-20 16:07:18|2025-08-20 17:47:28|             100.16667|             1.66944|
# |nirmallya|2025-08-20|Cursor Settings -...|2025-08-20 13:51:18|2025-08-20 14:03:46|              12.46667|             0.20778|
# |nirmallya|2025-08-20|  Transparent Window|2025-08-20 22:10:37|2025-08-20 22:31:36|              20.98333|             0.34972|
# |nirmallya|2025-08-20|ChatGPT - Free do...|2025-08-20 15:45:40|2025-08-20 16:08:39|              22.98333|             0.38306|
# |nirmallya|2025-08-20|localhost:3000/ca...|2025-08-20 13:36:31|2025-08-20 13:36:31|                   0.0|                 0.0|
# |nirmallya|2025-08-20|Prodipta Chakrabo...|2025-08-20 14:47:09|2025-08-20 14:48:09|                   1.0|             0.01667|
# |nirmallya|2025-08-20|     Screen Snipping|2025-08-20 20:02:35|2025-08-20 20:02:46|               0.18333|             0.00306|
# |nirmallya|2025-08-20|Interview Screene...|2025-08-20 13:15:43|2025-08-20 22:31:41|             555.96667|             9.26611|
# +---------+----------+--------------------+-------------------+-------------------+----------------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# ### group by type, application_name and windows title - together

# %%
# Aggregation pipeline to calculate min/max timestamps per user, per type, per application, per window title per day
pipeline_duration_all = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$group": {
            "_id": {
                "date": {
                    "$dateToString": {
                        "format": "%Y-%m-%d",
                        "date": "$timestamp",
                        "timezone": "Asia/Kolkata"
                    }
                },
                "type": "$type",
                "application_name": "$application.name",
                "window_title": "$window.title"
            },
            "min_timestamp": {"$min": "$timestamp"},
            "max_timestamp": {"$max": "$timestamp"}
        }
    },
    {
        "$project": {
            "date": "$_id.date",
            "type": "$_id.type",
            "application_name": "$_id.application_name",
            "window_title": "$_id.window_title",
            "min_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$min_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "max_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$max_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    }
]

pipeline_duration_all_json = json.dumps(pipeline_duration_all, default=json_util.default)


# Read MongoDB with the unified pipeline
df_all = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "agentactivities")
        .option("aggregation.pipeline", pipeline_duration_all_json)
        .load()
)

from pyspark.sql.functions import round as spark_round

# Calculate durations in Spark
df_final = (
    df_all
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .withColumn("min_ts", to_timestamp("min_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("max_ts", to_timestamp("max_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("total_duration_minutes", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 60, 5))
    .withColumn("total_duration_hours", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 3600, 5))
    .select(
        "username", "email", "role", 
        "date",
        "type", "application_name", "window_title",
        "min_timestamp", "max_timestamp",
        "total_duration_minutes", "total_duration_hours"
    )
)

df_final.show()
# Out:
# +---------+--------------------+--------+----------+----------------+--------------------+--------------------+-------------------+-------------------+----------------------+--------------------+
# | username|               email|    role|      date|            type|    application_name|        window_title|      min_timestamp|      max_timestamp|total_duration_minutes|total_duration_hours|
# +---------+--------------------+--------+----------+----------------+--------------------+--------------------+-------------------+-------------------+----------------------+--------------------+
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|       Google Chrome|[IS-1379] Job-sco...|2025-08-20 15:23:23|2025-08-20 15:23:33|               0.16667|             0.00278|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|              Cursor|              Cursor|2025-08-20 14:30:15|2025-08-20 18:27:24|                237.15|              3.9525|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|               Slack|Kuheli Das (DM) -...|2025-08-20 14:46:46|2025-08-20 14:46:46|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|               Slack|Prodipta Chakrabo...|2025-08-20 14:48:16|2025-08-20 21:29:30|             401.23333|             6.68722|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|       Google Chrome|Login - Google Ch...|2025-08-20 16:44:45|2025-08-20 16:44:55|               0.16667|             0.00278|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|       keystroke|            Electron|         klizo-agent|2025-08-20 22:32:03|2025-08-20 22:32:03|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|       keystroke|Windows Shell Exp...|Windows Shell Exp...|2025-08-20 12:55:19|2025-08-20 12:55:19|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|               Slack|Sourav Rooj (DM) ...|2025-08-20 21:52:02|2025-08-20 21:55:32|                   3.5|             0.05833|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|       keystroke|               Slack|  Transparent Window|2025-08-20 22:10:38|2025-08-20 22:31:36|              20.96667|             0.34944|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|    Windows Explorer|     Program Manager|2025-08-20 15:49:00|2025-08-20 15:51:16|               2.26667|             0.03778|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|       Google Chrome|Meet - Daily Scru...|2025-08-20 15:15:42|2025-08-20 15:44:40|              28.96667|             0.48278|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|       Google Chrome|Untitled - Google...|2025-08-20 16:07:18|2025-08-20 17:47:28|             100.16667|             1.66944|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|Application Frame...|     Microsoft Store|2025-08-20 15:57:57|2025-08-20 15:57:57|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|               Slack|      Slack - Huddle|2025-08-20 13:08:29|2025-08-20 18:20:53|                 312.4|             5.20667|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|               Slack|! Sourav Rooj (DM...|2025-08-20 14:42:49|2025-08-20 14:42:49|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|       Google Chrome|ChatGPT - Google ...|2025-08-20 16:32:31|2025-08-20 21:54:11|             321.66667|             5.36111|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|       Google Chrome|what codes does -...|2025-08-20 21:53:32|2025-08-20 21:53:32|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|       keystroke|       Google Chrome|loveable - Google...|2025-08-20 16:44:36|2025-08-20 16:44:36|                   0.0|                 0.0|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|    window_focus|               Slack|Activity - Klizo ...|2025-08-20 14:44:09|2025-08-20 14:44:14|               0.08333|             0.00139|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|       Google Chrome|Interview Screene...|2025-08-20 13:16:03|2025-08-20 22:26:32|             550.48333|             9.17472|
# +---------+--------------------+--------+----------+----------------+--------------------+--------------------+-------------------+-------------------+----------------------+--------------------+
# only showing top 20 rows

# %%
# Aggregation pipeline to calculate min/max timestamps per user, per type, per application, per window title per day
pipeline_duration_all = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$group": {
            "_id": {
                "date": {
                    "$dateToString": {
                        "format": "%Y-%m-%d",
                        "date": "$timestamp",
                        "timezone": "Asia/Kolkata"
                    }
                },
                "type": "$type",
                "application_name": "$application.name",
                "window_title": "$window.title"
            },
            "min_timestamp": {"$min": "$timestamp"},
            "max_timestamp": {"$max": "$timestamp"}
        }
    },
    {
        "$project": {
            "date": "$_id.date",
            "type": "$_id.type",
            "application_name": "$_id.application_name",
            "window_title": "$_id.window_title",
            "min_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$min_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "max_timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$max_timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    }
]

pipeline_duration_all_json = json.dumps(pipeline_duration_all, default=json_util.default)


from pyspark.sql.functions import round as spark_round, unix_timestamp, to_timestamp, min as spark_min, max as spark_max

# Step 1: Compute per-row durations (your existing df_final base)
df_final = (
    df_all
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .withColumn("min_ts", to_timestamp("min_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("max_ts", to_timestamp("max_timestamp", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("total_duration_minutes", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 60, 5))
    .withColumn("total_duration_hours", spark_round((unix_timestamp("max_ts") - unix_timestamp("min_ts")) / 3600, 5))
    .select(
        "username", "email", "role", 
        "date",
        "type", "application_name", "window_title",
        "min_timestamp", "max_timestamp",
        "total_duration_minutes", "total_duration_hours"
    )
)

# Step 2: Compute daily duration (max - min for the whole day)
df_daily = (
    df_final
    .groupBy("date")
    .agg(
        spark_min("min_timestamp").alias("day_min"),
        spark_max("max_timestamp").alias("day_max")
    )
    .withColumn("daily_duration_minutes", spark_round((unix_timestamp("day_max") - unix_timestamp("day_min")) / 60, 5))
    .withColumn("daily_duration_hours", spark_round((unix_timestamp("day_max") - unix_timestamp("day_min")) / 3600, 5))
    .select("date", "daily_duration_minutes", "daily_duration_hours")
)

# Step 3: Join back to original df_final
df_final_with_daily = (
    df_final
    .join(df_daily, on="date", how="left")
    .select(
        "username", #"email", "role", 
        "date",
        "type", "application_name", "window_title"
        # ,"min_timestamp", "max_timestamp",
        # "total_duration_minutes", "total_duration_hours",
        # "daily_duration_minutes", "daily_duration_hours"
    )
)

df_final_with_daily.show(100, truncate=False)
# Out:
# +---------+----------+----------------+-----------------------------+--------------------------------------------------------------------------------------------------------------+
# |username |date      |type            |application_name             |window_title                                                                                                  |
# +---------+----------+----------------+-----------------------------+--------------------------------------------------------------------------------------------------------------+
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |ChatGPT - Supriyo - Interview Screener - Google Chrome                                                        |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |Meet - kqt-xfjp-xye - Google Chrome                                                                           |
# |nirmallya|2025-08-20|activity_summary|Slack                        |interviewscreener-demo-updates (Channel) - Klizo Solutions - 2 new items - Slack                              |
# |nirmallya|2025-08-20|window_focus    |Windows Shell Experience Host|Windows Shell Experience Host                                                                                 |
# |nirmallya|2025-08-20|window_focus    |Windows Shell Experience Host|Action center                                                                                                 |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |MCQ and text type questions - Google Chrome                                                                   |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |code-conversations-hub - Lovable - Google Chrome                                                              |
# |nirmallya|2025-08-20|window_focus    |Cursor                       |page.tsx (Working Tree) (page.tsx) - coding-evaluation - Cursor                                               |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Attendance System Klizos - Login - Google Chrome                                                              |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |2 sprints - Interview Screener - Scrum Board - Jira - Google Chrome                                           |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Attendance System - Member’s Dashboard - Google Chrome                                                        |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Sourav Rooj (DM) - Klizo Solutions - 3 new items - Slack 🎤                                                   |
# |nirmallya|2025-08-20|window_focus    |Cursor                       |README.md - coding-evaluation - Cursor                                                                        |
# |nirmallya|2025-08-20|activity_summary|Search application           |Search                                                                                                        |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |AI Interview Assistant - Google Chrome                                                                        |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Prodipta Chakraborty (DM) - Klizo Solutions - 1 new item - Slack                                              |
# |nirmallya|2025-08-20|window_focus    |Windows Shell Experience Host|Network Connections                                                                                           |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |localhost:3000/candidate/test/test_1755610564928_9a0bean8f - Google Chrome                                    |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |localhost - Google Chrome                                                                                     |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |Untitled - Google Chrome                                                                                      |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |Jo Tere Sang - Blood Money | Official Music Video | Kunal Khemu | Mustafa Zahid - YouTube - Google Chrome     |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Supriyo Mondal (DM) - Klizo Solutions - 1 new item - Slack [Main] 🏠🔊                                        |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |what codes does - Google Search - Google Chrome                                                               |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |(94) Jo Tere Sang - Blood Money | Official Music Video | Kunal Khemu | Mustafa Zahid - YouTube - Google Chrome|
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |code-conversations-hub - Lovable - Google Chrome                                                              |
# |nirmallya|2025-08-20|window_focus    |Store                        |Microsoft Store                                                                                               |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Bitbucket - Google Chrome                                                                                     |
# |nirmallya|2025-08-20|window_focus    |Search application           |Search                                                                                                        |
# |nirmallya|2025-08-20|keystroke       |Slack                        |Sourav Rooj (DM) - Klizo Solutions - 3 new items - Slack [Main] 🏠🔊                                          |
# |nirmallya|2025-08-20|keystroke       |Slack                        |Sourav Rooj (DM) - Klizo Solutions - 3 new items - Slack [Main] 🏠🎤                                          |
# |nirmallya|2025-08-20|window_focus    |Cursor                       |package-lock.json (Working Tree) (package-lock.json) - coding-evaluation - Cursor                             |
# |nirmallya|2025-08-20|window_focus    |Visual Studio Code           |index.html - local-llm-code-evaluation - Visual Studio Code                                                   |
# |nirmallya|2025-08-20|keystroke       |Cursor                       |database.ts - coding-evaluation - Cursor                                                                      |
# |nirmallya|2025-08-20|window_focus    |Cursor                       |CreateUserModal.tsx - coding-evaluation - Cursor                                                              |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Prodipta Chakraborty (DM) - Klizo Solutions - 4 new items - Slack                                             |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |ChatGPT - Monday - Google Chrome                                                                              |
# |nirmallya|2025-08-20|keystroke       |Slack                        |Slack - Huddle                                                                                                |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Transparent Window                                                                                            |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Open                                                                                                          |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |ChatGPT - Supriyo - Interview Screener - Google Chrome                                                        |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Sourav Rooj (DM) - Klizo Solutions - 2 new items - Slack                                                      |
# |nirmallya|2025-08-20|activity_summary|Electron                     |klizo-agent                                                                                                   |
# |nirmallya|2025-08-20|keystroke       |Cursor                       |Cursor                                                                                                        |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |candidate_1755676016558_0ncb0to4o-submission_1755677038869_fgiah5lbf-1755678764741.pdf - Google Chrome        |
# |nirmallya|2025-08-20|keystroke       |Electron                     |Klizo Agent                                                                                                   |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |what codes does - Google Search - Google Chrome                                                               |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |www.youtube.com wants to                                                                                      |
# |nirmallya|2025-08-20|activity_summary|Cursor                       |utils.ts - coding-evaluation - Cursor                                                                         |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Lovable - Build for the web 20x faster - Google Chrome                                                        |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |Cursor - The AI Code Editor - Google Chrome                                                                   |
# |nirmallya|2025-08-20|activity_summary|Unknown                      |Unknown                                                                                                       |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Prodipta Chakraborty (DM) - Klizo Solutions - 2 new items - Slack [Main] 🏠🎤                                 |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |Attendance System - Member’s Dashboard - Google Chrome                                                        |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Huddle: unknown-channel - Klizo Solutions - Slack 🎤                                                          |
# |nirmallya|2025-08-20|activity_summary|Store                        |Microsoft Store                                                                                               |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Transparent Window                                                                                            |
# |nirmallya|2025-08-20|window_focus    |Slack                        |! Prodipta Chakraborty (DM) - Klizo Solutions - 2 new items - Slack                                           |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |[IS-1379] Job-scoped Slack integration (Phase 1) - Jira - Google Chrome                                       |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |Save As                                                                                                       |
# |nirmallya|2025-08-20|window_focus    |Windows Explorer             |Downloads                                                                                                     |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Sourav Rooj (DM) - Klizo Solutions - 3 new items - Slack [Main] 🏠🎤                                          |
# |nirmallya|2025-08-20|window_focus    |Task Manager                 |Task Manager                                                                                                  |
# |nirmallya|2025-08-20|window_focus    |Electron                     |Klizo Agent                                                                                                   |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |klizos / Repositories — Bitbucket - Google Chrome                                                             |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Activity - Klizo Solutions - 4 new items - Slack                                                              |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |Jira - Google Chrome                                                                                          |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |ChatGPT - Supriyo - Interview Screener - Google Chrome                                                        |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Meet - kqt-xfjp-xye - Google Chrome                                                                           |
# |nirmallya|2025-08-20|activity_summary|ScreenClippingHost.exe       |Screen Snipping                                                                                               |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |what codex does - Google Search - Google Chrome                                                               |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |loveable - Google Search - Google Chrome                                                                      |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |Open                                                                                                          |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |klizos / local-llm-code-evaluation — Bitbucket - Google Chrome                                                |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |ChatGPT - Monday - Google Chrome                                                                              |
# |nirmallya|2025-08-20|keystroke       |Settings                     |Settings                                                                                                      |
# |nirmallya|2025-08-20|keystroke       |Slack                        |Huddle: @Sourav Rooj - Klizo Solutions - Slack 🎤                                                             |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |chatgpy desktop download - Google Search - Google Chrome                                                      |
# |nirmallya|2025-08-20|keystroke       |Slack                        |Padma Dey (DM) - Klizo Solutions - 3 new items - Slack                                                        |
# |nirmallya|2025-08-20|activity_summary|Slack                        |Prodipta Chakraborty (DM) - Klizo Solutions - 3 new items - Slack                                             |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |YouTube - Google Chrome                                                                                       |
# |nirmallya|2025-08-20|window_focus    |Slack                        |interviewscreener-demo-updates (Channel) - Klizo Solutions - 1 new item - Slack                               |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Activity - Klizo Solutions - 2 new items - Slack 🔊                                                           |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Supriyo Mondal (DM) - Klizo Solutions - 3 new items - Slack                                                   |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Prodipta Chakraborty (DM) - Klizo Solutions - 3 new items - Slack                                             |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |localhost - Google Chrome                                                                                     |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Jo Tere Sang - Blood Money | Official Music Video | Kunal Khemu | Mustafa Zahid - YouTube - Google Chrome     |
# |nirmallya|2025-08-20|window_focus    |Slack                        |Padma Dey (DM) - Klizo Solutions - 1 new item - Slack                                                         |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |cursor/dashboard - Google Search - Google Chrome                                                              |
# |nirmallya|2025-08-20|window_focus    |Slack                        |is-jira (Channel) - Klizo Solutions - 2 new items - Slack                                                     |
# |nirmallya|2025-08-20|activity_summary|Electron                     |Klizo Agent                                                                                                   |
# |nirmallya|2025-08-20|window_focus    |Cursor                       |badge.tsx - coding-evaluation - Cursor                                                                        |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |ChatGPT - Twilio-Ashterisk-LLM - Google Chrome                                                                |
# |nirmallya|2025-08-20|activity_summary|Google Chrome                |ChatGPT on your desktop - Google Chrome                                                                       |
# |nirmallya|2025-08-20|activity_summary|Windows Shell Experience Host|Jump List for Nirmallya (klizos.com) - Chrome                                                                 |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |klizos / talentsync-fe — Bitbucket - Google Chrome                                                            |
# |nirmallya|2025-08-20|keystroke       |Slack                        |Slack                                                                                                         |
# |nirmallya|2025-08-20|activity_summary|Cursor                       |page.tsx (Working Tree) (page.tsx) - coding-evaluation - Cursor                                               |
# |nirmallya|2025-08-20|keystroke       |Google Chrome                |Codex - Google Chrome                                                                                         |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |Coding Evaluation - User Flow - Google Docs - Google Chrome                                                   |
# |nirmallya|2025-08-20|window_focus    |Google Chrome                |ChatGPT - Free download and install on Windows | Microsoft Store - Google Chrome                              |
# +---------+----------+----------------+-----------------------------+--------------------------------------------------------------------------------------------------------------+
# only showing top 100 rows

# %% [markdown]
# # STEP - 3

# %%
import json

activity_data = df_final_with_daily.toPandas().to_dict(orient="records")

activity_json = json.dumps(activity_data, indent=2, default=str)

with open("activity_log.json", "w", encoding="utf-8") as f:
    f.write(activity_json)

print("Activity log exported to activity_log.json")
print(f"Total records exported: {len(activity_data)}")

# %%
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import json

# Load GROQ_API_KEY from .env
load_dotenv()

# Initialize LLM
llm = ChatGroq(model="llama3-70b-8192", temperature=0)

# Convert Spark DataFrame → JSON
activity_data = df_final_with_daily.toPandas().to_dict(orient="records")
activity_json = json.dumps(activity_data, indent=2, default=str)

# Create prompt
prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a productivity analysis assistant."),
    ("user", """Analyze the following employee activity log and generate a structured productivity report.

The report should include:
- Employee name, report generation time
- Daily summary of activity patterns
- Top applications & websites used
- Any irrelevant/distracting activity
- Productivity rating (0–100) with reasoning
- Recommendations to improve
- A final JSON block with productivity_score, rating, and recommendations.

Employee: {username}
Date: {date}
Data:
{activity_json}
""")
])

# Format the prompt with values
prompt = prompt_template.format_messages(
    username=username,
    date=start_date.strftime('%Y-%m-%d'),
    activity_json=activity_json
)

# Call Groq
response = llm.invoke(prompt)

print(response.content)

# %%
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import json
import math

# Load GROQ_API_KEY from .env
load_dotenv()

# Initialize LLM
llm = ChatGroq(model="llama3-70b-8192", temperature=0)

# Convert Spark DataFrame → JSON-like dict
activity_data = df_final_with_daily.toPandas().to_dict(orient="records")

# Chunk the activity logs to avoid exceeding token limits
CHUNK_SIZE = 50   # adjust depending on avg row size
chunks = [activity_data[i:i+CHUNK_SIZE] for i in range(0, len(activity_data), CHUNK_SIZE)]

# Define summarization prompt
chunk_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a productivity analysis assistant. Summarize concisely."),
    ("user", """Summarize the following activity logs into a compact form with:
- Key apps/websites used
- Irrelevant/distractions
- Time distribution summary

Data:
{activity_chunk}
""")
])

chunk_summaries = []
for idx, chunk in enumerate(chunks):
    activity_json_chunk = json.dumps(chunk, indent=2, default=str)
    chunk_prompt = chunk_prompt_template.format_messages(
        activity_chunk=activity_json_chunk
    )
    response = llm.invoke(chunk_prompt)
    chunk_summaries.append(response.content)

# Now combine summaries into the final structured report
final_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a productivity analysis assistant."),
    ("user", """Based on the following summarized activity data, generate a structured productivity report.

The report should include:
- Employee name, report generation time
- Daily summary of activity patterns
- Top applications & websites used
- Any irrelevant/distracting activity
- Productivity rating (0–100) with reasoning
- Recommendations to improve
- A final JSON block with productivity_score, rating, and recommendations.

Employee: {username}
Date: {date}
Summarized Data:
{summaries}
""")
])

final_prompt = final_prompt_template.format_messages(
    username=username,
    date=start_date.strftime('%Y-%m-%d'),
    summaries="\n\n".join(chunk_summaries)
)

final_response = llm.invoke(final_prompt)
print(final_response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[50], line 39
#      35     activity_json_chunk = json.dumps(chunk, indent=2, default=str)
#      36     chunk_prompt = chunk_prompt_template.format_messages(
#      37         activity_chunk=activity_json_chunk
#      38     )
# ---> 39     response = llm.invoke(chunk_prompt)
#      40     chunk_summaries.append(response.content)
#      42 # Now combine summaries into the final structured report
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)   1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/langchain_groq/chat_models.py:527, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     522 message_dicts, params = self._create_message_dicts(messages, stop)
#     523 params = {
#     524     **params,
#     525     **kwargs,
#     526 }
# --> 527 response = self.client.create(messages=message_dicts, **params)
#     528 return self._create_chat_result(response, params)
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/groq/resources/chat/completions.py:378, in Completions.create(self, messages, model, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     184 def create(
#     185     self,
#     186     *,
#    (...)    233     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     234 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     235     """
#     236     Creates a model response for the given chat conversation.
#     237
#    (...)    376       timeout: Override the client-level default timeout for this request, in seconds
#     377     """
# --> 378     return self._post(
#     379         "/openai/v1/chat/completions",
#     380         body=maybe_transform(
#     381             {
#     382                 "messages": messages,
#     383                 "model": model,
#     384                 "exclude_domains": exclude_domains,
#     385                 "frequency_penalty": frequency_penalty,
#     386                 "function_call": function_call,
#     387                 "functions": functions,
#     388                 "include_domains": include_domains,
#     389                 "include_reasoning": include_reasoning,
#     390                 "logit_bias": logit_bias,
#     391                 "logprobs": logprobs,
#     392                 "max_completion_tokens": max_completion_tokens,
#     393                 "max_tokens": max_tokens,
#     394                 "metadata": metadata,
#     395                 "n": n,
#     396                 "parallel_tool_calls": parallel_tool_calls,
#     397                 "presence_penalty": presence_penalty,
#     398                 "reasoning_effort": reasoning_effort,
#     399                 "reasoning_format": reasoning_format,
#     400                 "response_format": response_format,
#     401                 "search_settings": search_settings,
#     402                 "seed": seed,
#     403                 "service_tier": service_tier,
#     404                 "stop": stop,
#     405                 "store": store,
#     406                 "stream": stream,
#     407                 "temperature": temperature,
#     408                 "tool_choice": tool_choice,
#     409                 "tools": tools,
#     410                 "top_logprobs": top_logprobs,
#     411                 "top_p": top_p,
#     412                 "user": user,
#     413             },
#     414             completion_create_params.CompletionCreateParams,
#     415         ),
#     416         options=make_request_options(
#     417             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     418         ),
#     419         cast_to=ChatCompletion,
#     420         stream=stream or False,
#     421         stream_cls=Stream[ChatCompletionChunk],
#     422     )
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/groq/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /mnt/d/padma/teramind/teramind_venv/lib/python3.12/site-packages/groq/_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jngt063xfzybyt7kbae0mt6z` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 3456, Requested 2555. Please try again in 101.999999ms. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
rows = df_final.count()
cols = len(df_final.columns)

print(f"df_final has {rows} rows and {cols} columns")
# Out:
# df_final has 263 rows and 9 columns

# %% [markdown]
# ## Raw Data

# %%
start_date = datetime.strptime(filter_date, "%Y-%m-%d")
end_date = start_date + timedelta(days=1)

pipeline_activities = [
    {
        "$match": {
            "userId": user_id,
            "timestamp": {
                "$gte": start_date,
                "$lt": end_date
            }
        }
    },
    {
        "$project": {
            "type": 1,
            "application_name": "$application.name",
            "window_title": "$window.title",
            # Extract date and convert UTC → IST
            "date": {
                "$dateToString": {
                    "format": "%Y-%m-%d",
                    "date": "$timestamp",
                    "timezone": "Asia/Kolkata"
                }
            },
            "timestamp": {
                "$dateToString": {
                    "format": "%Y-%m-%d %H:%M:%S",
                    "date": "$timestamp",
                    "timezone": "Asia/Kolkata"
                }
            }
        }
    },
    {
        "$sort": {"timestamp": 1}
    }
]

pipeline_activities_json = json.dumps(pipeline_activities, default=json_util.default)

# Load into Spark
df_activities = (
    spark.read
        .format("mongodb")
        .option("connection.uri", mongo_url)
        .option("database", "monitoring")
        .option("collection", "agentactivities")
        .option("aggregation.pipeline", pipeline_activities_json)
        .load()
)

# Add user metadata
df_activities = (
    df_activities
    .withColumn("username", lit(username))
    .withColumn("email", lit(user_email))
    .withColumn("role", lit(role))
    .select(
        "username", "email", "role",
        "date",
        "type", "application_name", "window_title",
        "timestamp"
    )
)

print(f"Total raw records: {df_activities.count()}")
df_activities.show(10, truncate=False)
# Out:
# Total raw records: 10230
# +---------+--------------------+--------+----------+----------------+----------------+------------+-------------------+
# |username |email               |role    |date      |type            |application_name|window_title|timestamp          |
# +---------+--------------------+--------+----------+----------------+----------------+------------+-------------------+
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Electron        |Klizo Agent |2025-08-20 12:53:04|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|keystroke       |Windows Explorer|NULL        |2025-08-20 12:53:04|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Windows Explorer|NULL        |2025-08-20 12:53:06|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Windows Explorer|NULL        |2025-08-20 12:53:11|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Windows Explorer|NULL        |2025-08-20 12:53:16|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Windows Explorer|NULL        |2025-08-20 12:53:21|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|activity_summary|Windows Explorer|NULL        |2025-08-20 12:53:26|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Windows Explorer|NULL        |2025-08-20 12:53:26|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|keystroke       |Windows Explorer|NULL        |2025-08-20 12:53:28|
# |nirmallya|nirmallya@klizos.com|employee|2025-08-20|window_focus    |Windows Explorer|NULL        |2025-08-20 12:53:31|
# +---------+--------------------+--------+----------+----------------+----------------+------------+-------------------+
# only showing top 10 rows

# %%
# Show first 5 rows
print("===== HEAD (first 5 rows) =====")
df_activities.limit(5).show(truncate=False)

# %%
from pyspark.sql import Row

last_rows = df_final.tail(5)
df_tail = spark.createDataFrame(last_rows)

print("===== TAIL (last 5 rows) =====")
df_tail.show(truncate=False)
